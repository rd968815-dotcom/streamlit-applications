# %%
print('hello,world')
# Out:
# hello,world

# %%
dishes= {
    'veg':['panner butter masala','aloo gobi'],
    'non-veg':['chiken biryani','mutton curry']
}


sorted_dishes = sorted(dishes['non-veg'])
sorted_dishes
# Out:
# ['chiken biryani', 'mutton curry']
